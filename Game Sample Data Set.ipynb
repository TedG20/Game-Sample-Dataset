# %%
import pandas as pd #import library

# %%
df = pd.read_csv("sample-csv-files-sample4.csv")

# %%
df.head()
# Out:
#    Game Number   "Game Length"
# 0            1              30
# 1            2              29
# 2            3              31
# 3            4              16
# 4            5              24

# %%
df_clean = df.dropna() #Drop rows with missing values

# %%
df_clean = df_clean.drop_duplicates() #remove duplicate entries

# %%
df.head()
# Out:
#    Game Number   "Game Length"
# 0            1              30
# 1            2              29
# 2            3              31
# 3            4              16
# 4            5              24

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(3, 2))
plt.bar(df_clean.index, df_clean.iloc[:, 0])
plt.xlabel("Game Number")
plt.ylabel("Game Length")
plt.tight_layout()
plt.show()
